# %%
import cv2
import mediapipe as mp

# %%
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()
mp_draw = mp.solutions.drawing_utils
cap = cv2.VideoCapture(0)

finger_tips = [8, 12, 16, 20]
thumb_tip = 4

# like_img = cv2.imread("images/like.png")
# like_img = cv2.resize(like_img, (200, 180))
#
# dislike_img = cv2.imread("images/dislike.png")
# dislike_img = cv2.resize(dislike_img, (200, 180))

while True:
    ret, img = cap.read()
    img = cv2.flip(img, 1)
    h, w, c = img.shape
    results = hands.process(img)

    if results.multi_hand_landmarks:
        for hand_landmark in results.multi_hand_landmarks:
            lm_list = []
            for id, lm in enumerate(hand_landmark.landmark):
                lm_list.append(lm)
            finger_fold_status = []
            for tip in finger_tips:
                x, y = int(lm_list[tip].x * w), int(lm_list[tip].y * h)
                # print(id, ":", x, y)
                #cv2.circle(img, (x, y), 15, (255, 0, 0), cv2.FILLED)

                if lm_list[tip].x < lm_list[tip - 2].x:
                    #cv2.circle(img, (x, y), 15, (0, 255, 0), cv2.FILLED)
                    finger_fold_status.append(True)
                else:
                    finger_fold_status.append(False)

            print(finger_fold_status)

            x, y = int(lm_list[8].x * w), int(lm_list[8].y * h)
            print(x, y)

            # stop
            if lm_list[4].y < lm_list[2].y and lm_list[8].y < lm_list[6].y and lm_list[12].y < lm_list[10].y and \
                    lm_list[16].y < lm_list[14].y and lm_list[20].y < lm_list[18].y and lm_list[17].x < lm_list[0].x < \
                    lm_list[5].x:
                cv2.putText(img, "Nawathwanna", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
                print("Nawathwanna")

            # Forward
            if lm_list[3].x > lm_list[4].x and lm_list[8].y < lm_list[6].y and lm_list[12].y > lm_list[10].y and \
                    lm_list[16].y > lm_list[14].y and lm_list[20].y > lm_list[18].y:
                cv2.putText(img, "Idiriyata", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
                print("Idiriyata")

            # Backward
            if lm_list[3].x > lm_list[4].x and lm_list[3].y < lm_list[4].y and lm_list[8].y > lm_list[6].y and lm_list[12].y < lm_list[10].y and \
                    lm_list[16].y < lm_list[14].y and lm_list[20].y < lm_list[18].y:
                cv2.putText(img, "Pasugami", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
                print("Pasugami")

            # Left
            if lm_list[4].y < lm_list[2].y and lm_list[8].x < lm_list[6].x and lm_list[12].x > lm_list[10].x and \
                    lm_list[16].x > lm_list[14].x and lm_list[20].x > lm_list[18].x and lm_list[5].x < lm_list[0].x:
                cv2.putText(img, "Wama", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
                print("Wama")

            # Right
            if lm_list[4].y < lm_list[2].y and lm_list[8].x > lm_list[6].x and lm_list[12].x < lm_list[10].x and \
                    lm_list[16].x < lm_list[14].x and lm_list[20].x < lm_list[18].x:
                cv2.putText(img, "Dakuna", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
                print("Dakuna")


            if all(finger_fold_status):
                # like
                if lm_list[thumb_tip].y < lm_list[thumb_tip - 1].y < lm_list[thumb_tip - 2].y and lm_list[0].x < lm_list[3].y:
                    print("Itha Hodai")
                    cv2.putText(img, "Itha Hodai", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)
                    # h, w, c = like_img.shape
                    # img[35:h + 35, 30:w + 30] = like_img
                # Dislike
                if lm_list[thumb_tip].y > lm_list[thumb_tip - 1].y > lm_list[thumb_tip - 2].y and lm_list[0].x < lm_list[3].y:
                    cv2.putText(img, "Itha Narakai", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
                    print("Itha Narakai")
                    # h, w, c = dislike_img.shape
                    # img[35:h + 35, 30:w + 30] = dislike_img


            mp_draw.draw_landmarks(img, hand_landmark,
                                   mp_hands.HAND_CONNECTIONS,
                                   mp_draw.DrawingSpec((0, 0, 255), 6, 3),
                                   mp_draw.DrawingSpec((0, 255, 0), 4, 2)
                                   )

    cv2.imshow("Hand Sign Detection", img)
    cv2.waitKey(1)
# Out:
# [False, False, False, True]
# 197 145
# STOP
# [True, False, True, True]
# 189 126
# STOP
# [True, True, True, True]
# 190 127
# STOP
# LIKE
# [True, False, True, True]
# 180 127
# STOP
# [True, True, True, True]
# 181 128
# STOP
# LIKE
# [True, True, True, True]
# 169 124
# STOP
# LIKE
# [True, True, True, True]
# 169 125
# STOP
# LIKE
# [True, True, True, True]
# 168 127
# STOP
# LIKE
# [True, True, True, True]
# 169 127
# STOP
# LIKE
# [True, True, True, True]
# 168 127
# STOP
# LIKE
# [True, True, True, True]
# 169 126
# STOP
# LIKE
# [True, True, True, True]
# 171 130
# STOP
# LIKE
# [False, True, True, True]
# 173 130
# STOP
# RIGHT
# [False, False, False, False]
# 181 222
# [False, False, False, False]
# 180 255
# [False, False, False, False]
# 179 258
# [False, False, False, False]
# 162 263
# [False, False, False, False]
# 157 256
# [True, False, False, False]
# 155 256
# [True, True, False, False]
# 144 244
# [True, False, False, False]
# 145 240
# [True, False, False, False]
# 146 240
# [False, False, False, False]
# 151 220
# [False, False, False, False]
# 149 217
# [False, False, False, False]
# 144 217
# [False, False, False, False]
# 142 206
# [False, False, False, False]
# 140 207
# [False, False, False, False]
# 139 171
# STOP
# [False, False, False, False]
# 140 169
# STOP
# [False, False, False, False]
# 141 140
# STOP
# [False, False, False, True]
# 140 138
# STOP
# [False, False, False, True]
# 141 138
# STOP
# [False, False, False, True]
# 140 139
# STOP
# [False, False, False, True]
# 141 140
# STOP
# [False, False, False, True]
# 143 141
# STOP
# [False, False, False, True]
# 143 141
# STOP
# [False, False, False, True]
# 143 141
# STOP
# [False, False, False, True]
# 142 140
# STOP
# [False, False, False, True]
# 143 140
# STOP
# [False, False, False, True]
# 143 141
# STOP
# [False, False, False, True]
# 144 142
# STOP
# [False, False, False, True]
# 144 142
# STOP
# [False, False, False, True]
# 141 142
# STOP
# [False, False, False, True]
# 142 141
# STOP
# [False, False, False, True]
# 142 141
# STOP
# [False, False, False, True]
# 140 143
# STOP
# [False, False, False, True]
# 141 143
# STOP
# [False, False, False, True]
# 141 143
# STOP
# [False, False, False, False]
# 142 232
# [False, False, False, True]
# 151 183
# STOP
# [False, False, False, True]
# 151 185
# STOP
# [False, False, False, True]
# 152 140
# STOP
# [False, False, False, True]
# 157 129
# STOP
# [False, False, False, True]
# 153 128
# STOP
# [False, False, False, True]
# 148 124
# STOP
# [False, False, False, True]
# 149 125
# STOP
# [False, False, False, True]
# 151 128
# STOP
# [False, False, False, True]
# 150 129
# STOP
# [False, False, False, True]
# 150 128
# STOP
# [False, False, False, True]
# 150 129
# STOP
# [False, False, False, True]
# 150 131
# STOP
# [False, False, False, True]
# 150 131
# STOP
# [False, False, False, True]
# 149 131
# STOP
# [False, False, False, True]
# 148 131
# STOP
# [False, False, False, True]
# 149 131
# STOP
# [False, False, False, True]
# 150 131
# STOP
# [False, False, False, True]
# 150 131
# STOP
# [False, False, False, True]
# 148 131
# STOP
# [False, False, False, True]
# 149 130
# STOP
# [False, False, False, True]
# 150 132
# STOP
# [False, False, False, True]
# 147 132
# STOP
# [False, False, False, True]
# 148 133
# STOP
# [False, False, False, True]
# 149 132
# STOP
# [False, False, False, True]
# 149 132
# STOP
# [False, False, False, True]
# 148 135
# STOP
# [False, False, False, True]
# 150 134
# STOP
# [False, False, False, True]
# 148 134
# STOP
# [False, False, False, True]
# 149 135
# STOP
# [False, False, False, True]
# 149 136
# STOP
# [False, False, False, True]
# 149 136
# STOP
# [False, False, False, True]
# 151 136
# STOP
# [False, False, False, True]
# 151 137
# STOP
# [False, False, False, True]
# 149 134
# STOP
# [False, False, False, True]
# 151 134
# STOP
# [False, False, False, True]
# 151 136
# STOP
# [False, False, False, True]
# 151 137
# STOP
# [False, False, False, True]
# 151 137
# STOP
# [False, False, False, True]
# 152 136
# STOP
# [False, False, False, True]
# 153 135
# STOP
# [False, False, False, True]
# 153 136
# STOP
# [False, False, False, True]
# 154 137
# STOP
# [False, False, False, True]
# 154 137
# STOP
# [False, False, False, True]
# 154 137
# STOP
# [False, False, False, True]
# 153 136
# STOP
# [False, False, False, True]
# 153 136
# STOP
# [False, False, False, True]
# 153 137
# STOP
# [False, False, False, True]
# 154 137
# STOP
# [False, False, False, True]
# 155 135
# STOP
# [False, False, False, True]
# 153 135
# STOP
# [False, False, False, True]
# 154 136
# STOP
# [False, False, False, True]
# 153 136
# STOP
# [False, False, False, True]
# 154 136
# STOP
# [False, False, False, True]
# 154 135
# STOP
# [False, False, False, True]
# 154 135
# STOP
# [False, False, False, True]
# 154 136
# STOP
# [False, False, False, True]
# 154 136
# STOP
# [False, False, False, True]
# 154 135
# STOP
# [False, False, False, True]
# 152 136
# STOP
# [False, False, False, True]
# 152 136
# STOP
# [False, False, False, True]
# 152 137
# STOP
# [False, False, False, True]
# 153 137
# STOP
# [False, False, False, True]
# 153 135
# STOP
# [False, False, False, True]
# 153 136
# STOP
# [False, False, False, True]
# 153 136
# STOP
# [False, False, False, True]
# 152 134
# STOP
# [False, False, False, True]
# 155 133
# STOP
# [False, False, False, True]
# 153 134
# STOP
# [False, False, False, True]
# 152 135
# STOP
# [False, False, False, True]
# 154 137
# STOP
# [False, False, False, True]
# 154 138
# STOP
# [False, False, False, True]
# 156 147
# STOP
# [False, False, False, False]
# 154 178
# STOP
# [False, False, False, False]
# 153 195
# STOP
# [True, True, True, True]
# 146 212
# LIKE
# [True, True, True, True]
# 133 199
# LIKE
# [True, True, True, True]
# 131 205
# LIKE
# [True, True, True, True]
# 131 208
# LIKE
# [True, True, True, True]
# 129 212
# LIKE
# [True, True, True, True]
# 129 216
# LIKE
# [True, True, True, True]
# 126 215
# LIKE
# [True, True, True, True]
# 127 216
# LIKE
# [True, True, True, True]
# 125 218
# LIKE
# [True, True, True, True]
# 125 221
# LIKE
# [True, True, True, True]
# 126 221
# LIKE
# [True, True, True, True]
# 127 220
# LIKE
# [True, True, True, True]
# 131 226
# LIKE
# [True, True, True, True]
# 128 226
# LIKE
# [True, True, True, True]
# 129 225
# LIKE
# [True, True, True, True]
# 131 228
# LIKE
# [True, True, True, True]
# 130 225
# LIKE
# [True, True, True, True]
# 133 227
# LIKE
# [True, True, True, True]
# 132 227
# LIKE
# [True, True, True, True]
# 132 227
# LIKE
# [True, True, True, True]
# 128 222
# LIKE
# [True, True, True, True]
# 131 223
# LIKE
# [True, True, True, True]
# 130 221
# LIKE
# [True, True, True, True]
# 131 223
# LIKE
# [True, True, True, True]
# 134 224
# LIKE
# [True, True, True, True]
# 131 223
# LIKE
# [True, True, True, True]
# 131 223
# LIKE
# [True, True, True, True]
# 131 220
# LIKE
# [True, True, True, True]
# 128 222
# LIKE
# [True, True, True, True]
# 129 224
# LIKE
# [True, True, True, True]
# 130 219
# LIKE
# [True, True, True, True]
# 130 219
# LIKE
# [True, True, True, True]
# 131 221
# LIKE
# [True, True, True, True]
# 131 224
# LIKE
# [True, True, True, True]
# 132 225
# LIKE
# [True, True, True, True]
# 133 222
# LIKE
# [True, True, True, True]
# 131 222
# LIKE
# [True, True, True, True]
# 134 222
# LIKE
# [True, True, True, True]
# 132 221
# LIKE
# [True, True, True, True]
# 137 227
# LIKE
# [True, True, True, True]
# 135 224
# LIKE
# [True, True, True, True]
# 132 224
# LIKE
# [True, True, True, True]
# 132 225
# LIKE
# [True, True, True, True]
# 131 225
# LIKE
# [True, True, True, True]
# 131 228
# LIKE
# [True, True, True, True]
# 130 224
# LIKE
# [True, True, True, True]
# 131 224
# LIKE
# [True, True, True, True]
# 134 226
# LIKE
# [True, True, True, True]
# 136 226
# LIKE
# [True, True, True, True]
# 132 225
# LIKE
# [True, True, True, True]
# 132 225
# LIKE
# [True, True, True, True]
# 133 226
# LIKE
# [True, True, True, True]
# 132 227
# LIKE
# [True, True, True, True]
# 132 228
# LIKE
# [True, True, True, True]
# 133 224
# LIKE
# [True, True, True, True]
# 133 225
# LIKE
# [True, True, True, True]
# 132 224
# LIKE
# [True, True, True, True]
# 132 226
# LIKE
# [True, True, True, True]
# 134 223
# LIKE
# [True, True, True, True]
# 134 223
# LIKE
# [True, True, True, True]
# 136 226
# LIKE
# [True, True, True, True]
# 134 223
# LIKE
# [True, True, True, True]
# 136 227
# LIKE
# [True, True, True, True]
# 134 222
# LIKE
# [True, True, True, True]
# 136 223
# LIKE
# [True, True, True, True]
# 132 220
# LIKE
# [True, True, True, True]
# 130 221
# LIKE
# [True, True, True, True]
# 131 223
# LIKE
# [True, True, True, True]
# 140 229
# LIKE
# [True, True, True, True]
# 136 226
# LIKE
# [True, True, True, True]
# 140 227
# LIKE
# [True, True, True, True]
# 140 225
# LIKE
# [True, True, True, True]
# 138 226
# LIKE
# [True, True, True, True]
# 134 222
# LIKE
# [True, True, True, True]
# 134 224
# LIKE
# [True, True, True, True]
# 148 227
# LIKE
# [True, True, True, True]
# 134 225
# LIKE
# [True, True, True, True]
# 138 230
# LIKE
# [True, True, True, True]
# 136 227
# LIKE
# [True, True, True, True]
# 127 226
# LIKE
# [True, True, True, True]
# 127 223
# LIKE
# [True, True, True, True]
# 120 225
# LIKE
# [True, True, True, True]
# 119 226
# LIKE
# [True, True, True, True]
# 122 221
# LIKE
# [True, True, True, True]
# 123 223
# LIKE
# [True, True, True, True]
# 126 224
# LIKE
# [True, True, True, True]
# 125 224
# LIKE
# [True, True, True, True]
# 124 226
# LIKE
# [True, True, True, True]
# 122 224
# LIKE
# [True, True, True, True]
# 124 221
# LIKE
# [True, True, True, True]
# 124 223
# LIKE
# [True, True, True, True]
# 125 223
# LIKE
# [True, True, True, True]
# 125 222
# LIKE
# [True, True, True, True]
# 125 224
# LIKE
# [True, True, True, True]
# 126 226
# LIKE
# [True, True, True, True]
# 125 225
# LIKE
# [True, True, True, True]
# 122 223
# LIKE
# [True, True, True, True]
# 124 223
# LIKE
# [True, True, True, True]
# 126 222
# LIKE
# [True, True, True, True]
# 127 225
# LIKE
# [True, True, True, True]
# 125 224
# LIKE
# [True, True, True, True]
# 127 225
# LIKE
# [True, True, True, True]
# 127 223
# LIKE
# [True, True, True, True]
# 128 223
# LIKE
# [True, True, True, True]
# 129 223
# LIKE
# [True, True, True, True]
# 126 220
# LIKE
# [True, True, True, True]
# 126 223
# LIKE
# [True, True, True, True]
# 130 223
# LIKE
# [True, True, True, True]
# 128 224
# LIKE
# [True, True, True, True]
# 126 224
# LIKE
# [True, True, True, True]
# 126 224
# LIKE
# [True, True, True, True]
# 124 223
# LIKE
# [True, True, True, True]
# 126 224
# LIKE
# [True, True, True, True]
# 127 225
# LIKE
# [True, True, True, True]
# 129 223
# LIKE
# [True, True, True, True]
# 126 224
# LIKE
# [True, True, True, True]
# 128 223
# LIKE
# [True, True, True, True]
# 125 223
# LIKE
# [True, True, True, True]
# 127 223
# LIKE
# [True, True, True, True]
# 130 225
# LIKE
# [True, True, True, True]
# 125 222
# LIKE
# [True, True, True, True]
# 127 222
# LIKE
# [True, True, True, True]
# 131 226
# LIKE
# [True, True, True, True]
# 129 224
# LIKE
# [True, True, True, True]
# 130 225
# LIKE
# [True, True, True, True]
# 127 220
# LIKE
# [True, True, True, True]
# 127 220
# LIKE
# [True, True, True, True]
# 126 221
# LIKE
# [True, True, True, True]
# 126 222
# LIKE
# [True, True, True, True]
# 124 221
# LIKE
# [True, True, True, True]
# 132 222
# LIKE
# [True, True, True, True]
# 129 225
# LIKE
# [True, True, True, True]
# 127 218
# LIKE
# [True, True, True, True]
# 127 220
# LIKE
# [True, True, True, True]
# 127 220
# LIKE
# [True, True, True, True]
# 129 222
# LIKE
# [True, True, True, True]
# 129 223
# LIKE
# [True, True, True, True]
# 100 189
# LIKE
# [True, True, True, True]
# 129 221
# LIKE
# [True, True, True, True]
# 131 224
# LIKE
# [True, True, True, True]
# 128 224
# LIKE
# [True, True, True, True]
# 134 228
# LIKE
# [True, True, True, True]
# 134 227
# LIKE
# [True, True, True, True]
# 129 223
# LIKE
# [True, True, True, True]
# 131 225
# LIKE
# [True, True, True, True]
# 127 223
# LIKE
# [True, True, True, True]
# 126 215
# LIKE
# [True, True, True, True]
# 133 224
# LIKE
# [True, True, True, True]
# 135 225
# LIKE
# [True, True, True, True]
# 129 224
# LIKE
# [True, True, True, True]
# 126 218
# LIKE
# [True, True, True, True]
# 125 217
# LIKE
# [True, True, True, True]
# 126 221
# LIKE
# [True, True, True, True]
# 133 224
# LIKE
# [True, True, True, True]
# 129 222
# LIKE
# [True, True, True, True]
# 127 223
# LIKE
# [True, True, True, True]
# 129 225
# LIKE
# [True, True, True, True]
# 126 222
# LIKE
# [True, True, True, True]
# 134 226
# LIKE
# [True, True, True, True]
# 132 226
# LIKE
# [True, True, True, True]
# 127 223
# LIKE
# [True, True, True, True]
# 128 222
# LIKE
# [True, True, True, True]
# 129 224
# LIKE
# [True, True, True, True]
# 127 220
# LIKE
# [True, True, True, True]
# 127 219
# LIKE
# [True, True, True, True]
# 130 223
# LIKE
# [True, True, True, True]
# 131 222
# LIKE
# [True, True, True, True]
# 129 221
# LIKE
# [True, True, True, True]
# 126 220
# LIKE
# [True, True, True, True]
# 126 220
# LIKE
# [True, True, True, True]
# 131 221
# LIKE
# [True, True, True, True]
# 129 224
# LIKE
# [True, True, True, True]
# 132 226
# LIKE
# [True, True, True, True]
# 130 223
# LIKE
# [True, True, True, True]
# 131 222
# LIKE
# [True, True, True, True]
# 128 222
# LIKE
# [True, True, True, True]
# 126 222
# LIKE
# [True, True, True, True]
# 129 222
# LIKE
# [True, True, True, True]
# 128 221
# LIKE
# [True, True, True, True]
# 130 223
# LIKE
# [True, True, True, True]
# 130 221
# LIKE
# [True, True, True, True]
# 129 220
# LIKE
# [True, True, True, True]
# 130 224
# LIKE
# [True, True, True, True]
# 130 223
# LIKE
# [True, True, True, True]
# 132 223
# LIKE
# [True, True, True, True]
# 132 220
# LIKE
# [True, True, True, True]
# 131 220
# LIKE
# [True, True, True, True]
# 134 225
# LIKE
# [True, True, True, True]
# 134 225
# LIKE
# [True, True, True, True]
# 128 220
# LIKE
# [True, True, True, True]
# 133 222
# LIKE
# [True, True, True, True]
# 132 222
# LIKE
# [True, True, True, True]
# 131 223
# LIKE
# [True, True, True, True]
# 127 224
# LIKE
# [True, True, True, True]
# 128 226
# LIKE
# [True, True, True, True]
# 132 224
# LIKE
# [True, True, True, True]
# 124 220
# LIKE
# [True, True, True, True]
# 132 229
# LIKE
# [True, True, True, True]
# 130 222
# LIKE
# [True, True, True, True]
# 128 224
# LIKE
# [True, True, True, True]
# 130 220
# LIKE
# [True, True, True, True]
# 131 222
# LIKE
# [True, True, True, True]
# 130 222
# LIKE
# [True, True, True, True]
# 130 225
# LIKE
# [True, True, True, True]
# 135 226
# LIKE
# [True, True, True, True]
# 128 219
# LIKE
# [True, True, True, True]
# 129 221
# LIKE
# [True, True, True, True]
# 130 226
# LIKE
# [True, True, True, True]
# 131 226
# LIKE
# [True, True, True, True]
# 129 225
# LIKE
# [True, True, True, True]
# 133 227
# LIKE
# [True, True, True, True]
# 129 222
# LIKE
# [True, True, True, True]
# 127 221
# LIKE
# [True, True, True, True]
# 129 223
# LIKE
# [True, True, True, True]
# 131 221
# LIKE
# [True, True, True, True]
# 128 224
# LIKE
# [True, True, True, True]
# 132 225
# LIKE
# [True, True, True, True]
# 128 219
# LIKE
# [True, True, True, True]
# 127 221
# LIKE
# [True, True, True, True]
# 125 223
# LIKE
# [True, True, True, True]
# 124 221
# LIKE
# [False, False, False, False]
# 150 225
# [True, True, True, True]
# 124 220
# LIKE
# [True, True, True, True]
# 125 221
# LIKE
# [True, True, True, True]
# 125 219
# LIKE
# [True, True, True, True]
# 126 218
# LIKE
# [True, True, True, True]
# 124 219
# LIKE
# [True, True, True, True]
# 127 220
# LIKE
# [True, True, True, True]
# 127 221
# LIKE
# [True, True, True, True]
# 127 222
# LIKE
# [True, True, True, True]
# 125 223
# LIKE
# [True, True, True, True]
# 127 225
# LIKE
# [True, True, True, True]
# 126 222
# LIKE
# [True, True, True, True]
# 125 220
# LIKE
# [True, True, True, True]
# 127 221
# LIKE
# [True, True, True, True]
# 124 220
# LIKE
# [True, True, True, True]
# 123 221
# LIKE
# [True, True, True, True]
# 125 221
# LIKE
# [True, True, True, True]
# 124 220
# LIKE
# [True, True, True, True]
# 124 221
# LIKE
# [True, True, True, True]
# 127 224
# LIKE
# [True, True, True, True]
# 126 221
# LIKE
# [True, True, True, True]
# 125 220
# LIKE
# [True, True, True, True]
# 122 223
# LIKE
# [True, True, True, True]
# 126 226
# LIKE
# [True, True, True, True]
# 121 218
# LIKE
# [True, True, True, True]
# 126 220
# LIKE
# [True, True, True, True]
# 125 220
# LIKE
# [True, True, True, True]
# 126 223
# LIKE
# [True, True, True, True]
# 130 225
# LIKE
# [True, True, True, True]
# 129 224
# LIKE
# [True, True, True, True]
# 134 225
# LIKE
# [True, True, True, True]
# 137 226
# LIKE
# [True, True, True, True]
# 129 226
# LIKE
# [True, True, True, True]
# 128 223
# LIKE
# [True, True, True, True]
# 127 222
# LIKE
# [True, True, True, True]
# 122 219
# LIKE
# [True, True, True, True]
# 127 222
# LIKE
# [True, True, True, True]
# 126 222
# LIKE
# [True, True, True, True]
# 133 226
# LIKE
# [True, True, True, True]
# 132 224
# LIKE
# [True, True, True, True]
# 128 223
# LIKE
# [True, True, True, True]
# 123 222
# LIKE
# [True, True, True, True]
# 123 224
# LIKE
# [True, True, True, True]
# 124 231
# LIKE
# [True, True, True, True]
# 120 232
# LIKE
# [True, True, True, True]
# 122 237
# LIKE
# [True, True, True, True]
# 124 234
# LIKE
# [True, True, True, True]
# 122 234
# LIKE
# [True, True, True, True]
# 121 233
# LIKE
# [True, True, True, True]
# 119 227
# LIKE
# [True, True, True, True]
# 118 231
# LIKE
# [True, True, True, True]
# 118 229
# LIKE
# [True, True, True, True]
# 118 230
# LIKE
# [True, True, True, True]
# 119 228
# LIKE
# [True, True, True, True]
# 119 229
# LIKE
# [True, True, True, True]
# 120 228
# LIKE
# [True, True, True, True]
# 128 226
# LIKE
# [True, True, True, True]
# 123 227
# LIKE
# [True, True, True, True]
# 119 225
# LIKE
# [True, True, True, True]
# 122 227
# LIKE
# [True, True, True, True]
# 117 225
# LIKE
# [True, True, True, True]
# 118 225
# LIKE
# [True, True, True, True]
# 116 222
# LIKE
# [True, True, True, True]
# 123 221
# LIKE
# [True, True, True, True]
# 120 223
# LIKE
# [True, True, True, True]
# 120 220
# LIKE
# [True, True, True, True]
# 120 221
# LIKE
# [True, True, True, True]
# 121 221
# LIKE
# [True, True, True, True]
# 120 219
# LIKE
# [True, True, True, True]
# 124 215
# LIKE
# [True, True, True, True]
# 121 214
# LIKE
# [True, True, True, True]
# 120 214
# LIKE
# [True, True, True, True]
# 119 214
# LIKE
# [True, True, True, True]
# 124 215
# LIKE
# [True, True, True, True]
# 120 217
# LIKE
# [True, True, True, True]
# 122 213
# LIKE
# [True, True, True, True]
# 123 213
# LIKE
# [True, True, True, True]
# 122 217
# LIKE
# [True, True, True, True]
# 124 219
# LIKE
# [True, True, True, True]
# 123 217
# LIKE
# [True, True, True, True]
# 121 221
# LIKE
# [True, True, True, True]
# 126 219
# LIKE
# [True, True, True, True]
# 126 220
# LIKE
# [True, True, True, True]
# 124 219
# LIKE
# [True, True, True, True]
# 124 218
# LIKE
# [True, True, True, True]
# 123 219
# LIKE
# [True, True, True, True]
# 121 216
# LIKE
# [True, True, True, True]
# 122 219
# LIKE
# [True, True, True, True]
# 121 215
# LIKE
# [True, True, True, True]
# 119 216
# LIKE
# [True, True, True, True]
# 120 216
# LIKE
# [True, True, True, True]
# 121 216
# LIKE
# [True, True, True, True]
# 126 218
# LIKE
# [True, True, True, True]
# 126 219
# LIKE
# [True, True, True, True]
# 124 221
# LIKE
# [True, True, True, True]
# 124 219
# LIKE
# [True, True, True, True]
# 125 219
# LIKE
# [True, True, True, True]
# 124 216
# LIKE
# [True, True, True, True]
# 125 218
# LIKE
# [True, True, True, True]
# 126 217
# LIKE
# [True, True, True, True]
# 122 217
# LIKE
# [True, True, True, True]
# 123 223
# LIKE
# [True, True, True, True]
# 122 221
# LIKE
# [True, True, True, True]
# 123 219
# LIKE
# [True, True, True, True]
# 122 217
# LIKE
# [True, True, True, True]
# 125 222
# LIKE
# [True, True, True, True]
# 124 217
# LIKE
# [True, True, True, True]
# 121 217
# LIKE
# [True, True, True, True]
# 121 213
# LIKE
# [True, True, True, True]
# 125 217
# LIKE
# [True, True, True, True]
# 123 212
# LIKE
# [True, True, True, True]
# 126 219
# LIKE
# [True, True, True, True]
# 125 218
# LIKE
# [True, True, True, True]
# 125 218
# LIKE
# [True, True, True, True]
# 126 218
# LIKE
# [True, True, True, True]
# 124 220
# LIKE
# [True, True, True, True]
# 125 216
# LIKE
# [True, True, True, True]
# 125 222
# LIKE
# [True, True, True, True]
# 128 220
# LIKE
# [True, True, True, True]
# 126 220
# LIKE
# [True, True, True, True]
# 126 219
# LIKE
# [False, False, False, False]
# 264 197
# [False, False, False, False]
# 247 214
# [False, False, False, False]
# 250 209
# [False, False, False, False]
# 231 210
# [False, False, False, False]
# 221 212
# [False, False, False, False]
# 213 219
# [False, False, False, False]
# 209 229
# [True, True, True, True]
# 249 214
# [True, True, True, True]
# 122 287
# LIKE
# [True, True, True, True]
# 123 293
# LIKE
# [True, True, True, True]
# 121 293
# LIKE
# [True, True, True, True]
# 115 289
# LIKE
# [True, True, True, True]
# 117 293
# LIKE
# [True, True, True, True]
# 112 288
# LIKE
# [True, True, True, True]
# 108 285
# LIKE
# [True, True, True, True]
# 108 287
# LIKE
# [True, True, True, True]
# 108 288
# LIKE
# [True, True, True, True]
# 114 293
# LIKE
# [True, True, True, True]
# 112 292
# LIKE
# [True, True, True, True]
# 111 291
# LIKE
# [True, True, True, True]
# 117 289
# LIKE
# [True, True, True, True]
# 112 293
# LIKE
# [True, True, True, True]
# 115 292
# LIKE
# [True, True, True, True]
# 114 291
# LIKE
# [True, True, True, True]
# 118 292
# LIKE
# [True, True, True, True]
# 118 292
# LIKE
# [True, True, True, True]
# 115 289
# LIKE
# [True, True, True, True]
# 118 287
# LIKE
# [True, True, True, True]
# 117 286
# LIKE
# [True, True, True, True]
# 118 284
# LIKE
# [True, True, True, True]
# 116 281
# LIKE
# [True, True, True, True]
# 114 281
# LIKE
# [True, True, True, True]
# 113 285
# LIKE
# [True, True, True, True]
# 112 280
# LIKE
# [True, True, True, True]
# 119 284
# LIKE
# [True, True, True, True]
# 116 281
# LIKE
# [True, True, True, True]
# 117 282
# LIKE
# [True, True, True, True]
# 119 287
# LIKE
# [True, True, True, True]
# 119 283
# LIKE
# [True, True, True, True]
# 118 282
# LIKE
# [True, True, True, True]
# 117 284
# LIKE
# [True, True, True, True]
# 115 279
# LIKE
# [True, True, True, True]
# 118 282
# LIKE
# [True, True, True, True]
# 118 283
# LIKE
# [True, True, True, True]
# 117 283
# LIKE
# [True, True, True, True]
# 117 281
# LIKE
# [True, True, True, True]
# 118 281
# LIKE
# [True, True, True, True]
# 119 282
# LIKE
# [True, True, True, True]
# 118 279
# LIKE
# [True, True, True, True]
# 119 283
# LIKE
# [True, True, True, True]
# 116 280
# LIKE
# [True, True, True, True]
# 115 280
# LIKE
# [True, True, True, True]
# 120 278
# LIKE
# [True, True, True, True]
# 119 280
# LIKE
# [True, True, True, True]
# 120 278
# LIKE
# [True, True, True, False]
# 122 281
# [True, True, True, True]
# 121 280
# LIKE
# [True, True, True, True]
# 119 278
# LIKE
# [True, True, True, True]
# 118 278
# LIKE
# [True, True, True, True]
# 119 280
# LIKE
# [True, True, True, True]
# 118 280
# LIKE
# [True, True, True, False]
# 123 283
# [True, True, True, True]
# 116 281
# LIKE
# [True, True, True, False]
# 124 283
# [True, True, False, False]
# 124 283
# [True, True, True, True]
# 120 282
# LIKE
# [True, True, True, True]
# 118 283
# LIKE
# [True, True, True, True]
# 114 245
# LIKE
# [True, True, True, True]
# 113 271
# LIKE
# [True, True, True, True]
# 102 269
# LIKE
# [True, True, True, True]
# 100 271
# LIKE
# [True, True, True, True]
# 94 272
# LIKE
# [True, True, True, True]
# 95 276
# LIKE
# [True, True, True, True]
# 97 279
# LIKE
# [True, True, True, True]
# 98 280
# LIKE
# [True, True, True, True]
# 108 273
# LIKE
# [True, True, True, True]
# 103 276
# LIKE
# [False, True, True, True]
# 118 278
# RIGHT
# [True, True, True, True]
# 104 276
# LIKE
# [False, False, False, False]
# 123 279
# [True, True, True, True]
# 104 276
# LIKE
# [True, True, True, True]
# 115 280
# LIKE
# [True, True, True, True]
# 106 279
# LIKE
# [True, True, True, True]
# 109 279
# [True, True, True, True]
# 107 279
# LIKE
# [True, True, True, False]
# 114 276
# [True, True, True, True]
# 107 280
# LIKE
# [True, True, True, True]
# 116 279
# LIKE
# [True, True, True, True]
# 107 279
# LIKE
# [True, True, True, True]
# 103 278
# LIKE
# [True, True, True, True]
# 99 275
# LIKE
# [True, True, True, True]
# 102 274
# LIKE
# [True, True, True, True]
# 107 277
# LIKE
# [True, True, True, True]
# 106 275
# LIKE
# [True, True, True, True]
# 105 274
# LIKE
# [True, True, True, True]
# 106 279
# LIKE
# [True, True, True, True]
# 104 276
# LIKE
# [True, True, True, True]
# 105 277
# LIKE
# [True, True, True, True]
# 105 274
# LIKE
# [True, True, True, True]
# 104 276
# LIKE
# [True, True, True, True]
# 105 277
# LIKE
# [True, True, True, True]
# 104 273
# LIKE
# [True, True, True, True]
# 106 277
# LIKE
# [True, True, True, True]
# 118 275
# LIKE
# [True, True, True, True]
# 108 279
# LIKE
# [True, True, True, True]
# 114 274
# LIKE
# [True, True, True, True]
# 105 275
# LIKE
# [True, True, True, True]
# 114 274
# LIKE
# [True, True, True, True]
# 104 273
# LIKE
# [True, True, True, True]
# 113 278
# LIKE
# [True, True, True, True]
# 103 274
# LIKE
# [True, True, True, True]
# 112 276
# [True, True, True, True]
# 105 275
# LIKE
# [True, True, True, True]
# 115 281
# LIKE
# [True, True, True, True]
# 109 282
# LIKE
# [True, True, True, True]
# 107 280
# LIKE
# [True, True, True, True]
# 107 279
# LIKE
# [False, False, False, False]
# 136 275
# [True, True, True, True]
# 106 276
# LIKE
# [True, True, True, True]
# 120 281
# LIKE
# [True, True, True, True]
# 107 277
# LIKE
# [True, True, True, True]
# 111 280
# LIKE
# [True, True, True, True]
# 106 275
# LIKE
# [True, True, True, True]
# 105 273
# LIKE
# [True, True, True, True]
# 109 273
# LIKE
# [True, True, True, True]
# 110 273
# LIKE
# [True, True, True, True]
# 110 273
# LIKE
# [True, True, True, True]
# 111 274
# LIKE
# [True, True, True, True]
# 111 282
# LIKE
# [True, True, True, True]
# 109 272
# LIKE
# [True, True, True, True]
# 107 272
# LIKE
# [True, True, True, True]
# 110 276
# LIKE
# [True, True, True, True]
# 108 274
# LIKE
# [True, True, True, True]
# 108 275
# LIKE
# [True, True, True, True]
# 106 274
# LIKE
# [True, True, True, True]
# 106 273
# LIKE
# [True, True, True, True]
# 108 274
# LIKE
# [True, True, True, True]
# 106 275
# LIKE
# [True, True, True, True]
# 110 282
# LIKE
# [True, True, True, True]
# 105 277
# LIKE
# [True, True, True, True]
# 106 277
# LIKE
# [True, True, True, True]
# 107 278
# LIKE
# [True, True, True, True]
# 109 273
# LIKE
# [True, True, True, True]
# 107 270
# LIKE
# [True, True, True, True]
# 110 275
# LIKE
# [True, True, True, True]
# 107 267
# LIKE
# [False, False, False, False]
# 136 270
# [True, True, True, True]
# 110 271
# LIKE
# [True, True, True, True]
# 110 267
# LIKE
# [True, True, True, True]
# 109 267
# LIKE
# [True, True, True, True]
# 110 268
# LIKE
# [True, True, True, True]
# 112 269
# LIKE
# [True, True, True, True]
# 111 268
# LIKE
# [True, True, True, True]
# 111 272
# LIKE
# [True, True, True, True]
# 125 272
# LIKE
# [True, True, True, True]
# 111 265
# LIKE
# [True, True, True, True]
# 115 271
# LIKE
# [True, True, True, True]
# 115 271
# LIKE
# [True, True, True, True]
# 113 270
# LIKE
# [True, True, True, True]
# 119 268
# LIKE
# [True, True, True, True]
# 113 268
# LIKE
# [True, True, True, True]
# 115 267
# LIKE
# [True, True, True, True]
# 108 267
# LIKE
# [True, True, True, True]
# 108 263
# LIKE
# [True, True, True, True]
# 114 265
# LIKE
# [True, True, True, True]
# 117 266
# LIKE
# [True, True, True, True]
# 108 265
# LIKE
# [True, True, True, True]
# 115 267
# LIKE
# [False, True, True, True]
# 130 267
# RIGHT
# [True, True, True, True]
# 113 268
# LIKE
# [True, True, True, True]
# 110 268
# LIKE
# [True, True, True, True]
# 112 267
# LIKE
# [True, True, True, True]
# 129 266
# LIKE
# [True, True, True, True]
# 110 263
# LIKE
# [True, True, True, True]
# 109 265
# LIKE
# [False, False, False, False]
# 140 261
# [True, True, True, True]
# 108 264
# LIKE
# [True, True, True, True]
# 123 276
# LIKE
# [True, True, True, True]
# 107 266
# LIKE
# [True, True, True, True]
# 109 264
# LIKE
# [True, True, True, True]
# 111 264
# LIKE
# [True, True, True, True]
# 115 267
# LIKE
# [True, True, True, True]
# 116 264
# LIKE
# [True, True, True, True]
# 118 271
# LIKE
# [True, True, True, True]
# 116 268
# LIKE
# [True, True, True, True]
# 124 244
# LIKE
# [True, True, True, True]
# 124 247
# LIKE
# [True, True, True, True]
# 121 249
# LIKE
# [True, True, True, True]
# 120 254
# LIKE
# [True, True, True, True]
# 120 253
# LIKE
# [True, True, True, True]
# 130 255
# LIKE
# [True, True, True, True]
# 117 255
# LIKE
# [True, True, True, True]
# 123 261
# LIKE
# [True, True, True, True]
# 116 257
# LIKE
# [True, True, True, True]
# 127 264
# [True, True, True, True]
# 116 256
# LIKE
# [True, True, True, True]
# 121 263
# LIKE
# [True, True, True, True]
# 114 255
# LIKE
# [True, True, True, True]
# 132 261
# LIKE
# [True, True, True, True]
# 115 259
# LIKE
# [True, True, True, True]
# 111 256
# LIKE
# [True, True, True, True]
# 112 258
# LIKE
# [True, True, True, True]
# 116 256
# LIKE
# [True, True, True, True]
# 112 259
# LIKE
# [True, True, True, True]
# 113 259
# LIKE
# [True, True, True, True]
# 113 257
# LIKE
# [True, True, True, True]
# 116 262
# LIKE
# [True, True, True, True]
# 115 257
# LIKE
# [True, True, True, True]
# 116 259
# LIKE
# [True, True, True, True]
# 114 260
# LIKE
# [True, True, True, True]
# 116 263
# LIKE
# [True, True, True, True]
# 119 265
# LIKE
# [True, True, True, True]
# 118 262
# LIKE
# [True, True, True, True]
# 119 264
# LIKE
# [False, True, True, True]
# 139 264
# RIGHT
# [True, True, True, True]
# 117 259
# LIKE
# [True, True, True, True]
# 120 262
# LIKE
# [True, True, True, True]
# 117 260
# LIKE
# [True, True, True, True]
# 116 261
# LIKE
# [True, True, True, True]
# 116 260
# LIKE
# [True, True, True, True]
# 117 260
# LIKE
# [True, True, True, True]
# 117 260
# LIKE
# [True, True, True, True]
# 116 259
# LIKE
# [True, True, True, True]
# 131 257
# LIKE
# [True, True, True, True]
# 117 258
# LIKE
# [True, True, True, True]
# 119 262
# LIKE
# [True, True, True, True]
# 118 258
# LIKE
# [True, True, True, True]
# 116 261
# LIKE
# [True, True, True, True]
# 122 258
# LIKE
# [True, True, True, True]
# 119 257
# LIKE
# [True, True, True, True]
# 120 258
# LIKE
# [True, True, True, True]
# 119 257
# LIKE
# [True, True, True, True]
# 124 262
# LIKE
# [True, True, True, True]
# 118 260
# LIKE
# [True, True, True, True]
# 118 257
# LIKE
# [False, False, True, True]
# 146 255
# [True, True, True, True]
# 119 258
# LIKE
# [True, True, True, True]
# 132 263
# LIKE
# [True, True, True, True]
# 117 255
# LIKE
# [True, True, True, True]
# 131 262
# LIKE
# [True, True, True, True]
# 118 257
# LIKE
# [True, True, True, True]
# 116 256
# LIKE
# [True, True, True, True]
# 115 254
# LIKE
# [True, True, True, True]
# 115 258
# LIKE
# [True, True, True, True]
# 118 258
# LIKE
# [True, True, True, True]
# 121 261
# LIKE
# [True, True, True, True]
# 124 261
# LIKE
# [True, True, True, True]
# 118 261
# LIKE
# [True, True, True, True]
# 118 260
# LIKE
# [True, True, True, True]
# 119 256
# LIKE
# [True, True, True, True]
# 117 259
# LIKE
# [True, True, True, True]
# 123 254
# LIKE
# [True, True, True, True]
# 118 260
# LIKE
# [True, True, True, True]
# 119 261
# LIKE
# [True, True, True, True]
# 118 260
# LIKE
# [False, False, False, False]
# 145 252
# [True, True, True, True]
# 117 257
# LIKE
# [True, True, True, True]
# 126 261
# LIKE
# [True, True, True, True]
# 118 257
# LIKE
# [True, True, True, True]
# 116 258
# LIKE
# [True, True, True, True]
# 114 255
# LIKE
# [True, True, True, True]
# 118 261
# LIKE
# [True, True, True, True]
# 117 260
# LIKE
# [True, True, True, True]
# 117 258
# LIKE
# [True, True, True, True]
# 116 259
# LIKE
# [True, True, True, True]
# 118 260
# LIKE
# [True, True, True, True]
# 117 259
# LIKE
# [True, True, True, True]
# 118 258
# LIKE
# [True, True, True, True]
# 117 258
# LIKE
# [True, True, True, True]
# 123 262
# LIKE
# [True, True, True, True]
# 120 264
# LIKE
# [True, True, True, True]
# 113 259
# LIKE
# [True, True, True, True]
# 125 259
# LIKE
# [True, True, True, True]
# 121 264
# LIKE
# [True, True, True, True]
# 120 257
# LIKE
# [True, True, True, True]
# 118 259
# LIKE
# [True, True, True, True]
# 117 258
# LIKE
# [True, True, True, True]
# 118 258
# LIKE
# [True, True, True, True]
# 120 260
# LIKE
# [True, True, True, True]
# 124 264
# LIKE
# [False, False, True, True]
# 142 259
# [True, True, True, True]
# 117 261
# LIKE
# [True, True, True, True]
# 119 257
# LIKE
# [False, True, True, True]
# 139 256
# RIGHT
# [True, True, True, True]
# 119 262
# LIKE
# [False, False, False, False]
# 143 261
# [True, True, True, True]
# 118 259
# LIKE
# [True, True, True, True]
# 127 263
# LIKE
# [True, True, True, True]
# 118 260
# LIKE
# [True, True, True, False]
# 137 269
# [True, True, True, True]
# 117 259
# LIKE
# [False, False, True, True]
# 141 259
# [True, True, True, True]
# 117 256
# LIKE
# [False, False, False, False]
# 146 258
# [True, True, True, True]
# 118 260
# LIKE
# [False, True, True, True]
# 138 264
# RIGHT
# [True, True, True, True]
# 118 258
# LIKE
# [True, True, True, True]
# 131 262
# LIKE
# [True, True, True, True]
# 117 260
# LIKE
# [False, False, True, False]
# 139 264
# [True, True, True, True]
# 118 258
# LIKE
# [True, True, True, True]
# 117 255
# LIKE
# [True, True, True, True]
# 118 259
# LIKE
# [True, True, True, True]
# 118 259
# LIKE
# [True, True, True, True]
# 120 264
# LIKE
# [True, True, True, True]
# 116 259
# LIKE
# [True, True, True, True]
# 131 267
# LIKE
# [True, True, True, True]
# 118 259
# LIKE
# [True, False, False, False]
# 95 125
# FORWARD
# [True, False, False, False]
# 73 118
# FORWARD
# [True, False, False, False]
# 11 170
# FORWARD
# [True, True, True, True]
# 128 299
# LIKE
# [False, False, False, False]
# 140 300
# [False, False, False, False]
# 145 301
# [True, True, True, True]
# 132 302
# LIKE
# [True, True, True, True]
# 127 300
# LIKE
# [True, True, True, True]
# 121 292
# LIKE
# [True, True, True, True]
# 116 299
# LIKE
# [True, True, True, True]
# 116 299
# LIKE
# [True, True, True, True]
# 112 295
# LIKE
# [True, True, True, True]
# 114 293
# LIKE
# [True, True, True, True]
# 115 293
# LIKE
# [True, True, True, True]
# 116 294
# LIKE
# [True, True, True, True]
# 114 295
# LIKE
# [True, True, True, True]
# 118 294
# LIKE
# [True, True, True, True]
# 116 297
# LIKE
# [True, True, True, True]
# 118 299
# LIKE
# [True, True, True, False]
# 124 297
# [True, True, True, False]
# 130 296
# [False, False, False, False]
# 141 295
# [True, True, True, False]
# 135 293
# [True, True, False, False]
# 133 296
# [True, True, False, False]
# 133 295
# [True, True, True, False]
# 132 299
# [True, True, True, False]
# 132 293
# [True, True, True, True]
# 131 298
# LIKE
# [True, True, True, True]
# 124 297
# LIKE
# [True, True, True, True]
# 122 295
# LIKE
# [True, True, True, False]
# 134 301
# [True, True, True, True]
# 124 293
# LIKE
# [True, True, True, True]
# 129 294
# LIKE
# [True, True, True, True]
# 127 292
# LIKE
# [True, True, False, False]
# 135 288
# [True, True, True, False]
# 132 291
# [True, True, False, False]
# 137 287
# [True, True, True, False]
# 128 288
# [True, True, True, True]
# 131 290
# LIKE
# [True, True, True, True]
# 132 288
# LIKE
# [True, True, True, True]
# 130 286
# LIKE
# [True, True, False, False]
# 137 283
# [True, True, False, False]
# 143 292
# [False, False, False, False]
# 148 290
# [False, False, False, False]
# 147 280
# [True, True, False, False]
# 140 282
# [True, True, True, True]
# 128 287
# LIKE
# [True, True, True, True]
# 129 288
# LIKE
# [True, True, False, False]
# 142 290
# [True, True, False, False]
# 137 285
# [True, True, True, False]
# 132 289
# [True, True, True, True]
# 130 286
# LIKE
# [True, True, True, True]
# 130 284
# LIKE
# [True, True, False, False]
# 140 286
# [True, True, True, False]
# 135 287
# [True, True, True, True]
# 131 282
# LIKE
# [True, True, True, False]
# 134 288
# [True, True, True, True]
# 130 282
# LIKE
# [True, True, True, False]
# 135 288
# [False, False, False, False]
# 149 276
# [False, False, False, False]
# 144 275
# [False, False, False, False]
# 147 277
# [True, True, False, False]
# 145 283
# [False, True, False, False]
# 144 278
# [True, True, True, True]
# 132 289
# LIKE
# [True, True, True, True]
# 130 287
# LIKE
# [True, True, True, True]
# 133 290
# LIKE
# [True, True, True, True]
# 132 290
# LIKE
# [True, True, True, True]
# 135 294
# LIKE
# [True, True, True, True]
# 133 297
# LIKE
# [True, True, True, True]
# 134 305
# LIKE
# [True, True, True, True]
# 123 231
# DISLIKE
# [True, True, True, True]
# 122 232
# DISLIKE
# [True, True, True, True]
# 124 227
# DISLIKE
# [True, True, True, True]
# 128 228
# DISLIKE
# [True, True, True, True]
# 120 226
# DISLIKE
# [True, True, True, True]
# 121 224
# DISLIKE
# [True, True, True, True]
# 116 222
# DISLIKE
# [True, True, True, True]
# 117 222
# DISLIKE
# [True, True, True, True]
# 120 221
# DISLIKE
# [True, True, True, True]
# 119 227
# DISLIKE
# [True, True, True, True]
# 125 228
# DISLIKE
# [True, True, True, True]
# 123 229
# DISLIKE
# [True, True, True, True]
# 121 229
# DISLIKE
# [True, True, True, True]
# 121 229
# DISLIKE
# [True, True, True, True]
# 124 229
# DISLIKE
# [True, True, True, True]
# 125 231
# DISLIKE
# [True, True, True, True]
# 123 232
# DISLIKE
# [True, True, True, True]
# 129 231
# DISLIKE
# [True, True, True, True]
# 126 233
# DISLIKE
# [True, True, True, True]
# 126 233
# DISLIKE
# [True, True, True, True]
# 127 232
# DISLIKE
# [True, True, True, True]
# 123 232
# DISLIKE
# [True, True, True, True]
# 124 232
# DISLIKE
# [True, True, True, True]
# 127 231
# DISLIKE
# [True, True, True, True]
# 123 232
# DISLIKE
# [True, True, True, True]
# 124 232
# DISLIKE
# [True, True, True, True]
# 123 233
# DISLIKE
# [True, True, True, True]
# 128 232
# DISLIKE
# [True, True, True, True]
# 128 231
# DISLIKE
# [True, True, True, True]
# 128 230
# DISLIKE
# [True, True, True, True]
# 127 231
# DISLIKE
# [True, True, True, True]
# 127 231
# DISLIKE
# [True, True, True, True]
# 129 231
# DISLIKE
# [True, True, True, True]
# 129 232
# DISLIKE
# [True, True, True, True]
# 129 232
# DISLIKE
# [True, True, True, True]
# 127 231
# DISLIKE
# [True, True, True, True]
# 126 229
# DISLIKE
# [True, True, True, True]
# 129 231
# DISLIKE
# [True, True, True, True]
# 129 232
# DISLIKE
# [True, True, True, True]
# 128 233
# DISLIKE
# [True, True, True, True]
# 131 229
# DISLIKE
# [True, True, True, True]
# 129 234
# DISLIKE
# [True, True, True, True]
# 127 233
# DISLIKE
# [True, True, True, True]
# 124 232
# DISLIKE
# [True, True, True, True]
# 127 234
# DISLIKE
# [True, True, True, True]
# 127 235
# DISLIKE
# [True, True, True, True]
# 127 236
# DISLIKE
# [True, True, True, True]
# 127 236
# DISLIKE
# [True, True, True, True]
# 129 229
# DISLIKE
# [True, True, True, True]
# 131 231
# DISLIKE
# [True, True, True, True]
# 131 231
# DISLIKE
# [True, True, True, True]
# 130 230
# DISLIKE
# [True, True, True, True]
# 127 231
# DISLIKE
# [True, True, True, True]
# 131 233
# DISLIKE
# [True, True, True, True]
# 131 233
# DISLIKE
# [True, True, True, True]
# 128 234
# DISLIKE
# [True, True, True, True]
# 128 234
# DISLIKE
# [True, True, True, True]
# 129 232
# DISLIKE
# [True, True, True, True]
# 129 232
# DISLIKE
# [True, True, True, True]
# 129 233
# DISLIKE
# [True, True, True, True]
# 129 233
# DISLIKE
# [True, True, True, True]
# 126 232
# DISLIKE
# [True, True, True, True]
# 130 232
# DISLIKE
# [True, True, True, True]
# 128 232
# DISLIKE
# [True, True, True, True]
# 131 234
# DISLIKE
# [True, True, True, True]
# 133 231
# DISLIKE
# [True, True, True, True]
# 132 232
# DISLIKE
# [True, True, True, True]
# 129 234
# DISLIKE
# [True, True, True, True]
# 132 235
# DISLIKE
# [True, True, True, True]
# 131 235
# DISLIKE
# [True, True, True, True]
# 129 234
# DISLIKE
# [True, True, True, True]
# 130 232
# DISLIKE
# [True, True, True, True]
# 132 233
# DISLIKE
# [True, True, True, True]
# 129 232
# DISLIKE
# [True, True, True, True]
# 129 231
# DISLIKE
# [True, True, True, True]
# 132 234
# DISLIKE
# [True, True, True, True]
# 131 232
# DISLIKE
# [True, True, True, True]
# 130 232
# DISLIKE
# [True, True, True, True]
# 128 232
# DISLIKE
# [True, True, True, True]
# 132 232
# DISLIKE
# [True, True, True, True]
# 132 233
# DISLIKE
# [True, True, True, True]
# 130 233
# DISLIKE
# [True, True, True, True]
# 134 233
# DISLIKE
# [True, True, True, True]
# 135 233
# DISLIKE
# [True, True, True, True]
# 135 233
# DISLIKE
# [True, True, True, True]
# 132 231
# DISLIKE
# [True, True, True, True]
# 132 233
# DISLIKE
# [True, True, True, True]
# 131 233
# DISLIKE
# [True, True, True, True]
# 131 235
# DISLIKE
# [True, True, True, True]
# 131 234
# DISLIKE
# [True, True, True, True]
# 132 232
# DISLIKE
# [True, True, True, True]
# 132 233
# DISLIKE
# [True, True, True, True]
# 131 233
# DISLIKE
# [True, True, True, True]
# 131 232
# DISLIKE
# [True, True, True, True]
# 129 232
# DISLIKE
# [True, True, True, True]
# 131 232
# DISLIKE
# [True, True, True, True]
# 132 231
# DISLIKE
# [True, True, True, True]
# 135 231
# DISLIKE
# [True, True, True, True]
# 136 230
# DISLIKE
# [True, True, True, True]
# 136 230
# DISLIKE
# [True, True, True, True]
# 133 232
# DISLIKE
# [True, True, True, True]
# 139 231
# DISLIKE
# [True, True, True, True]
# 130 230
# DISLIKE
# [True, True, True, True]
# 130 230
# DISLIKE
# [True, True, True, True]
# 132 229
# DISLIKE
# [True, True, True, True]
# 134 229
# DISLIKE
# [True, True, True, True]
# 135 229
# DISLIKE
# [True, True, True, True]
# 131 229
# DISLIKE
# [True, True, True, True]
# 133 232
# DISLIKE
# [True, True, True, True]
# 131 232
# DISLIKE
# [True, True, True, True]
# 128 230
# DISLIKE
# [True, True, True, True]
# 136 230
# DISLIKE
# [True, True, True, True]
# 134 229
# DISLIKE
# [True, True, True, True]
# 133 228
# DISLIKE
# [True, True, True, True]
# 133 231
# DISLIKE
# [True, True, True, True]
# 131 229
# DISLIKE
# [True, True, True, True]
# 132 230
# DISLIKE
# [True, True, True, True]
# 132 230
# DISLIKE
# [True, True, True, True]
# 133 231
# DISLIKE
# [True, True, True, True]
# 134 231
# DISLIKE
# [True, True, True, True]
# 134 230
# DISLIKE
# [True, True, True, True]
# 137 229
# DISLIKE
# [True, True, True, True]
# 132 231
# DISLIKE
# [True, True, True, True]
# 132 231
# DISLIKE
# [True, True, True, True]
# 134 234
# DISLIKE
# [True, True, True, True]
# 131 232
# DISLIKE
# [True, True, True, True]
# 134 229
# DISLIKE
# [True, True, True, True]
# 129 231
# DISLIKE
# [True, True, True, True]
# 133 230
# DISLIKE
# [True, True, True, True]
# 134 231
# DISLIKE
# [True, True, True, True]
# 130 230
# DISLIKE
# [True, True, True, True]
# 131 230
# DISLIKE
# [True, True, True, True]
# 130 231
# DISLIKE
# [True, True, True, True]
# 135 231
# DISLIKE
# [True, True, True, True]
# 134 228
# DISLIKE
# [True, True, True, True]
# 132 228
# DISLIKE
# [True, True, True, True]
# 133 229
# DISLIKE
# [True, True, True, True]
# 135 230
# DISLIKE
# [True, True, True, True]
# 135 231
# DISLIKE
# [True, True, True, True]
# 133 230
# DISLIKE
# [True, True, True, True]
# 134 229
# DISLIKE
# [True, True, True, True]
# 135 228
# DISLIKE
# [True, True, True, True]
# 133 229
# DISLIKE
# [True, True, True, True]
# 133 229
# DISLIKE
# [True, True, True, True]
# 134 229
# DISLIKE
# [True, True, True, True]
# 131 229
# DISLIKE
# [True, True, True, True]
# 133 229
# DISLIKE
# [True, True, True, True]
# 133 232
# DISLIKE
# [True, True, True, True]
# 131 230
# DISLIKE
# [True, True, True, True]
# 133 229
# DISLIKE
# [True, True, True, True]
# 132 233
# DISLIKE
# [True, True, True, True]
# 134 228
# DISLIKE
# [True, True, True, True]
# 134 228
# DISLIKE
# [True, True, True, True]
# 135 231
# DISLIKE
# [True, True, True, True]
# 135 230
# DISLIKE
# [True, True, True, True]
# 135 231
# DISLIKE
# [True, True, True, True]
# 132 231
# DISLIKE
# [True, True, True, True]
# 133 230
# DISLIKE
# [True, True, True, True]
# 131 231
# DISLIKE
# [True, True, True, True]
# 135 231
# DISLIKE
# [True, True, True, True]
# 135 231
# DISLIKE
# [True, True, True, True]
# 134 239
# DISLIKE
# [True, True, True, True]
# 154 252
# DISLIKE
# [True, True, True, True]
# 160 252
# DISLIKE
# [True, True, True, True]
# 408 209
# [True, True, True, True]
# 394 196
# [True, True, True, True]
# 396 197
# [True, True, True, True]
# 387 199
# [True, True, True, True]
# 386 199
# [True, True, True, True]
# 385 199
# [True, True, True, True]
# 384 199
# [True, True, True, True]
# 384 200
# [True, True, True, True]
# 382 199
# [True, True, True, True]
# 383 199
# [True, True, True, True]
# 383 198
# [True, True, True, True]
# 385 197
# [True, True, True, True]
# 382 194
# [True, True, True, True]
# 382 195
# [True, True, True, True]
# 374 198
# [True, True, True, True]
# 371 199
# [True, True, True, True]
# 369 198
# [True, True, True, True]
# 362 198
# [True, True, True, True]
# 359 199
# [True, True, True, True]
# 359 200
# [True, True, True, True]
# 351 198
# FORWARD
# [True, True, True, True]
# 348 202
# [True, True, True, True]
# 348 199
# FORWARD
# [True, True, True, True]
# 348 199
# FORWARD
# [True, True, True, True]
# 347 196
# FORWARD
# [True, True, True, True]
# 347 196
# FORWARD
# [True, True, True, True]
# 347 197
# FORWARD
# [True, True, True, True]
# 343 198
# FORWARD
# [True, True, True, True]
# 344 199
# [True, True, True, True]
# 347 198
# [True, True, True, True]
# 346 198
# FORWARD
# [True, True, True, True]
# 346 199
# [True, True, True, True]
# 347 198
# FORWARD
# [True, True, True, True]
# 349 198
# [True, True, True, True]
# 348 196
# FORWARD
# [True, True, True, True]
# 349 197
# FORWARD
# [True, True, True, True]
# 351 197
# FORWARD
# [True, True, True, True]
# 352 196
# FORWARD
# [True, True, True, True]
# 352 197
# FORWARD
# [True, True, True, True]
# 353 198
# [True, True, True, True]
# 353 196
# [True, True, True, True]
# 352 197
# [True, True, True, True]
# 351 196
# [True, True, True, True]
# 351 195
# [True, True, True, True]
# 350 196
# [True, True, True, True]
# 351 194
# [True, True, True, True]
# 351 195
# [True, True, True, True]
# 352 196
# [True, True, True, True]
# 352 197
# [True, True, True, True]
# 352 196
# [True, True, True, True]
# 351 194
# [True, True, True, True]
# 351 195
# [True, True, True, True]
# 351 195
# [True, True, True, True]
# 351 195
# [True, True, True, True]
# 351 194
# [True, True, True, True]
# 351 194
# [True, True, True, True]
# 349 193
# [True, True, True, True]
# 348 194
# [True, True, True, True]
# 349 193
# [True, True, True, True]
# 347 194
# [True, True, True, True]
# 347 192
# [True, True, True, True]
# 347 192
# [True, True, True, True]
# 347 190
# [True, True, True, True]
# 346 191
# [True, True, True, True]
# 346 192
# [True, True, True, True]
# 345 193
# [True, True, True, True]
# 345 190
# [True, True, True, True]
# 345 191
# [True, True, True, True]
# 344 191
# [True, True, True, True]
# 345 189
# [True, True, True, True]
# 346 192
# [True, True, True, True]
# 343 190
# [True, True, True, True]
# 343 189
# [True, True, True, True]
# 342 189
# [True, True, True, True]
# 343 190
# [True, True, True, True]
# 343 190
# [True, True, True, True]
# 342 190
# [True, True, True, True]
# 343 190
# [True, True, True, True]
# 342 190
# [True, True, True, True]
# 342 190
# [True, True, True, True]
# 342 190
# [True, True, True, True]
# 343 190
# [True, True, True, True]
# 342 193
# [True, True, True, True]
# 341 191
# [True, True, True, True]
# 335 201
# [True, True, True, True]
# 332 201
# [True, True, True, True]
# 332 195
# [True, True, True, True]
# 333 196
# [True, True, True, True]
# 331 196
# [True, True, True, True]
# 330 193
# FORWARD
# [True, True, True, True]
# 330 194
# FORWARD
# [True, True, True, True]
# 334 191
# [True, True, True, True]
# 338 185
# FORWARD
# [True, True, True, True]
# 338 184
# FORWARD
# [True, True, True, True]
# 349 171
# [True, True, True, True]
# 349 165
# FORWARD
# [True, True, True, True]
# 348 164
# [True, True, True, True]
# 347 165
# FORWARD
# [True, True, True, True]
# 344 168
# FORWARD
# [True, True, True, True]
# 343 172
# FORWARD
# [True, True, True, True]
# 342 168
# FORWARD
# [True, True, True, True]
# 343 168
# FORWARD
# [True, True, True, True]
# 344 169
# FORWARD
# [True, True, True, True]
# 342 170
# FORWARD
# [True, True, True, True]
# 343 169
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 343 172
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 344 170
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 346 174
# FORWARD
# [True, True, True, True]
# 343 172
# FORWARD
# [True, True, True, True]
# 344 170
# FORWARD
# [True, True, True, True]
# 343 170
# FORWARD
# [True, True, True, True]
# 344 169
# FORWARD
# [True, True, True, True]
# 343 172
# FORWARD
# [True, True, True, True]
# 341 173
# FORWARD
# [True, True, True, True]
# 341 172
# FORWARD
# [True, True, True, True]
# 343 172
# FORWARD
# [True, True, True, True]
# 346 172
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 344 170
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 344 170
# FORWARD
# [True, True, True, True]
# 343 170
# FORWARD
# [True, True, True, True]
# 344 168
# FORWARD
# [True, True, True, True]
# 343 169
# FORWARD
# [True, True, True, True]
# 343 170
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 344 170
# FORWARD
# [True, True, True, True]
# 342 170
# FORWARD
# [True, True, True, True]
# 344 171
# FORWARD
# [True, True, True, True]
# 344 170
# FORWARD
# [True, True, True, True]
# 347 170
# FORWARD
# [True, True, True, True]
# 345 168
# FORWARD
# [True, True, True, True]
# 345 173
# FORWARD
# [True, True, True, True]
# 345 170
# FORWARD
# [True, True, True, True]
# 346 170
# FORWARD
# [True, True, True, True]
# 350 175
# FORWARD
# [True, True, True, True]
# 346 170
# FORWARD
# [True, True, True, True]
# 343 171
# FORWARD
# [True, True, True, True]
# 345 170
# FORWARD
# [True, True, True, True]
# 344 170
# FORWARD
# [True, True, True, True]
# 345 169
# FORWARD
# [True, True, True, True]
# 345 172
# FORWARD
# [True, True, True, True]
# 349 175
# FORWARD
# [True, True, True, True]
# 349 175
# FORWARD
# [True, True, True, True]
# 326 198
# [True, True, True, True]
# 320 198
# [True, True, True, True]
# 321 197
# [True, True, True, True]
# 321 197
# [True, True, True, True]
# 323 201
# [True, True, True, True]
# 320 201
# [True, True, True, True]
# 320 200
# [True, True, True, True]
# 321 202
# [True, True, True, True]
# 323 204
# [True, True, True, True]
# 328 208
# [True, True, True, True]
# 328 207
# [True, True, True, True]
# 333 211
# [True, True, True, True]
# 332 210
# [True, True, True, True]
# 332 207
# [True, True, True, True]
# 329 202
# [True, True, True, True]
# 325 202
# [True, True, True, True]
# 325 202
# [True, True, True, True]
# 318 200
# [True, True, True, True]
# 318 200
# [True, True, True, True]
# 316 201
# [True, True, True, True]
# 314 199
# [True, True, True, True]
# 314 199
# [True, True, True, True]
# 314 199
# [True, True, True, True]
# 315 200
# [True, True, True, True]
# 314 201
# [True, True, True, True]
# 314 202
# [True, True, True, True]
# 317 201
# [True, True, True, True]
# 317 201
# [True, True, True, True]
# 317 204
# [True, True, True, True]
# 318 205
# [True, True, True, True]
# 317 206
# [True, True, True, True]
# 320 203
# [True, True, True, True]
# 321 205
# [True, True, True, True]
# 321 206
# [True, True, True, True]
# 324 206
# [True, True, True, True]
# 324 206
# [True, True, True, True]
# 322 205
# [True, True, True, True]
# 323 204
# [True, True, True, True]
# 322 204
# [True, True, True, True]
# 323 204
# [True, True, True, True]
# 322 205
# [True, True, True, True]
# 321 207
# [True, True, True, True]
# 321 205
# [True, True, True, True]
# 319 205
# [True, True, True, True]
# 318 207
# [True, True, True, True]
# 317 207
# [True, True, True, True]
# 316 203
# [True, True, True, True]
# 313 197
# [True, True, True, True]
# 311 199
# BACKWARD
# [True, True, True, True]
# 309 203
# [True, True, True, True]
# 311 205
# [True, True, True, True]
# 312 206
# [True, True, True, True]
# 309 204
# [True, True, True, True]
# 307 204
# [True, True, True, True]
# 310 206
# [True, True, True, True]
# 310 205
# [True, True, True, True]
# 310 205
# [True, True, True, True]
# 309 204
# [True, True, True, True]
# 310 203
# [True, True, True, True]
# 310 203
# [True, True, True, True]
# 308 200
# [True, True, True, True]
# 307 200
# [True, True, True, True]
# 308 200
# [True, True, True, True]
# 307 200
# [True, True, True, True]
# 309 199
# [True, True, True, True]
# 309 200
# [True, True, True, True]
# 309 197
# [True, True, True, True]
# 308 197
# [True, True, True, True]
# 308 198
# [True, True, True, True]
# 307 198
# [True, True, True, True]
# 307 196
# [True, True, True, True]
# 308 197
# [True, True, True, True]
# 307 197
# [True, True, True, True]
# 308 197
# [True, True, True, True]
# 306 193
# [True, True, True, True]
# 307 194
# [True, True, True, True]
# 307 194
# [True, True, True, True]
# 309 194
# [True, True, True, True]
# 306 193
# [True, True, True, True]
# 306 193
# [True, True, True, True]
# 309 193
# [True, True, True, True]
# 309 192
# [True, True, True, True]
# 310 191
# [True, True, True, True]
# 308 192
# [True, True, True, True]
# 308 192
# [True, True, True, True]
# 305 192
# [True, True, True, True]
# 305 189
# [True, True, True, True]
# 305 190
# [True, True, True, True]
# 305 191
# [True, True, True, True]
# 305 192
# [True, True, True, True]
# 305 192
# [True, True, True, True]
# 305 192
# [True, True, True, True]
# 303 189
# [True, True, True, True]
# 300 187
# [True, True, True, True]
# 297 185
# [True, True, True, True]
# 297 186
# [True, True, True, True]
# 297 185
# [True, True, True, True]
# 298 185
# [True, True, True, True]
# 302 186
# [True, True, True, True]
# 301 187
# [True, True, True, True]
# 299 187
# [True, True, True, True]
# 301 188
# [True, True, True, True]
# 301 185
# [True, True, True, True]
# 299 186
# [True, True, True, True]
# 298 188
# [True, True, True, True]
# 298 188
# [True, True, True, True]
# 302 193
# [True, True, True, True]
# 306 196
# ...
# 321 218
# BACKWARD
# [True, True, True, True]
# 321 217
# BACKWARD
# [True, True, True, True]
# 321 217
# BACKWARD
# [True, True, True, True]
# 322 217
# BACKWARD
# [True, True, True, True]
# 320 215
# BACKWARD
# [True, True, True, True]
# 319 216
# BACKWARD
# [True, True, True, True]
# 319 216
# BACKWARD
# [True, True, True, True]
# 321 215
# BACKWARD
# [True, True, True, True]
# 320 213
# BACKWARD
# [True, True, True, True]
# 320 213
# BACKWARD
# [True, True, True, True]
# 321 215
# BACKWARD
# [True, True, True, True]
# 320 214
# BACKWARD
# [True, True, True, True]
# 321 213
# BACKWARD
# [True, True, True, True]
# 323 216
# BACKWARD
# [True, True, True, True]
# 323 216
# BACKWARD
# [True, True, True, True]
# 322 215
# BACKWARD
# [True, True, True, True]
# 320 214
# BACKWARD
# [True, True, True, True]
# 320 213
# BACKWARD
# [True, True, True, True]
# 321 213
# BACKWARD
# [True, True, True, True]
# 321 213
# BACKWARD
# [True, True, True, True]
# 321 213
# BACKWARD
# [True, True, True, True]
# 321 212
# BACKWARD
# [True, True, True, True]
# 321 210
# BACKWARD
# [True, True, True, True]
# 321 209
# BACKWARD
# [True, True, True, True]
# 321 210
# BACKWARD
# [True, True, True, True]
# 321 212
# BACKWARD
# [True, True, True, True]
# 320 212
# BACKWARD
# [True, True, True, True]
# 322 211
# BACKWARD
# [True, True, True, True]
# 322 211
# BACKWARD
# [True, True, True, True]
# 322 210
# BACKWARD
# [True, True, True, True]
# 321 211
# BACKWARD
# [True, True, True, True]
# 321 211
# BACKWARD
# [True, True, True, True]
# 331 211
# BACKWARD
# [False, False, False, False]
# 401 230
# [False, False, False, False]
# 397 229
# [True, True, True, True]
# 238 199
# LIKE
# [True, True, True, True]
# 236 208
# LIKE
# [True, True, True, True]
# 246 201
# LIKE
# [True, True, True, True]
# 249 206
# LIKE
# [True, True, True, True]
# 250 203
# LIKE
# [True, True, True, True]
# 253 206
# LIKE
# [True, True, True, True]
# 249 205
# LIKE
# [True, True, True, True]
# 255 194
# LIKE
# [True, True, True, True]
# 252 196
# LIKE
# [True, True, True, True]
# 253 203
# LIKE
# [True, True, True, True]
# 247 204
# LIKE
# [True, True, True, True]
# 247 206
# LIKE
# [True, True, True, True]
# 245 208
# LIKE
# [True, True, True, True]
# 244 211
# LIKE
# [True, True, True, True]
# 244 204
# LIKE
# [True, False, False, False]
# 314 204
# LEFT
# [True, False, False, False]
# 307 213
# LEFT
# [True, False, False, False]
# 306 214
# LEFT
# [True, False, False, False]
# 307 221
# LEFT
# [True, False, False, False]
# 308 218
# LEFT
# [True, False, False, False]
# 308 218
# LEFT
# [True, False, False, False]
# 312 219
# LEFT
# [True, False, False, False]
# 313 217
# LEFT
# [True, False, False, False]
# 314 217
# LEFT
# [True, False, False, False]
# 316 216
# LEFT
# [True, False, False, False]
# 316 215
# LEFT
# [True, False, False, False]
# 315 215
# LEFT
# [True, False, False, False]
# 315 214
# LEFT
# [True, False, False, False]
# 315 213
# LEFT
# [True, False, False, False]
# 314 213
# LEFT
# [True, False, False, False]
# 315 210
# LEFT
# [True, False, False, False]
# 318 209
# LEFT
# [True, False, False, False]
# 317 209
# LEFT
# [True, False, False, False]
# 317 206
# LEFT
# [True, False, False, False]
# 319 205
# LEFT
# [True, False, False, False]
# 318 205
# LEFT
# [True, False, False, False]
# 318 200
# LEFT
# [True, False, False, False]
# 320 200
# LEFT
# [True, False, False, False]
# 320 200
# LEFT
# [True, False, False, False]
# 321 198
# LEFT
# [True, False, False, False]
# 321 197
# LEFT
# [True, False, False, False]
# 321 197
# LEFT
# [True, False, False, False]
# 324 197
# LEFT
# [True, False, False, False]
# 324 198
# LEFT
# [True, False, False, False]
# 324 198
# LEFT
# [True, False, False, False]
# 323 197
# LEFT
# [True, False, False, False]
# 335 198
# LEFT
# [True, False, False, False]
# 323 197
# LEFT
# [True, False, False, False]
# 324 197
# LEFT
# [True, False, False, False]
# 321 197
# LEFT
# [True, False, False, False]
# 322 196
# LEFT
# [True, False, False, False]
# 323 196
# LEFT
# [True, False, False, False]
# 323 196
# LEFT
# [True, False, False, False]
# 323 196
# LEFT
# [True, False, False, False]
# 322 195
# LEFT
# [True, False, False, False]
# 321 196
# LEFT
# [True, False, False, False]
# 322 195
# LEFT
# [True, False, False, False]
# 321 195
# LEFT
# [True, False, False, False]
# 322 194
# LEFT
# [True, False, False, False]
# 322 193
# LEFT
# [True, False, False, False]
# 321 195
# LEFT
# [True, False, False, False]
# 321 194
# LEFT
# [True, False, False, False]
# 320 194
# LEFT
# [True, False, False, False]
# 319 193
# LEFT
# [True, False, False, False]
# 321 192
# LEFT
# [True, False, False, False]
# 321 192
# LEFT
# [True, False, False, False]
# 321 192
# LEFT
# [True, False, False, False]
# 320 192
# LEFT
# [True, False, False, False]
# 320 191
# LEFT
# [True, False, False, False]
# 321 191
# LEFT
# [True, False, False, False]
# 321 191
# LEFT
# [True, False, False, False]
# 319 190
# LEFT
# [True, False, False, False]
# 320 191
# LEFT
# [True, False, False, False]
# 319 191
# LEFT
# [True, False, False, False]
# 321 191
# LEFT
# [True, False, False, False]
# 321 190
# LEFT
# [True, False, False, False]
# 320 190
# LEFT
# [True, False, False, False]
# 322 190
# LEFT
# [True, False, False, False]
# 322 188
# LEFT
# [True, False, False, False]
# 322 189
# LEFT
# [True, False, False, False]
# 324 190
# LEFT
# [True, False, False, False]
# 322 189
# LEFT
# [True, False, False, False]
# 323 190
# LEFT
# [True, False, False, False]
# 324 189
# LEFT
# [True, False, False, False]
# 323 189
# LEFT
# [True, False, False, False]
# 322 189
# LEFT
# [True, False, False, False]
# 324 189
# LEFT
# [True, False, False, False]
# 324 188
# LEFT
# [True, False, False, False]
# 323 188
# LEFT
# [True, False, False, False]
# 324 189
# LEFT
# [True, False, False, False]
# 322 188
# LEFT
# [True, False, False, False]
# 323 189
# LEFT
# [True, False, False, False]
# 323 189
# LEFT
# [True, False, False, False]
# 322 187
# LEFT
# [True, False, False, False]
# 322 188
# LEFT
# [True, False, False, False]
# 324 190
# LEFT
# [True, False, False, False]
# 324 188
# LEFT
# [True, False, False, False]
# 324 188
# LEFT
# [True, False, False, False]
# 352 186
# LEFT
# [True, False, False, False]
# 325 188
# LEFT
# [True, False, False, False]
# 325 189
# LEFT
# [True, False, False, False]
# 325 189
# LEFT
# [True, False, False, False]
# 326 188
# LEFT
# [True, False, False, False]
# 326 188
# LEFT
# [True, False, False, False]
# 326 187
# LEFT
# [True, False, False, False]
# 344 187
# LEFT
# [True, False, False, False]
# 325 189
# LEFT
# [True, False, False, False]
# 324 189
# LEFT
# [True, False, False, False]
# 325 188
# LEFT
# [True, False, False, False]
# 327 188
# LEFT
# [True, False, False, False]
# 326 188
# LEFT
# [True, False, False, False]
# 324 187
# LEFT
# [True, False, False, False]
# 325 188
# LEFT
# [True, False, False, False]
# 325 187
# LEFT
# [True, False, False, False]
# 323 187
# LEFT
# [True, False, False, False]
# 326 186
# LEFT
# [True, False, False, False]
# 326 186
# LEFT
# [True, False, False, False]
# 326 185
# LEFT
# [True, False, False, False]
# 326 185
# LEFT
# [True, False, False, False]
# 326 184
# LEFT
# [True, False, False, False]
# 326 184
# LEFT
# [True, False, False, False]
# 326 185
# LEFT
# [True, False, False, False]
# 342 185
# LEFT
# [True, False, False, False]
# 327 185
# LEFT
# [True, False, False, False]
# 326 185
# LEFT
# [True, False, False, False]
# 326 185
# LEFT
# [True, False, False, False]
# 328 184
# LEFT
# [True, False, False, False]
# 329 184
# LEFT
# [True, False, False, False]
# 329 184
# LEFT
# [True, True, True, True]
# 371 185
# [True, False, False, False]
# 330 184
# LEFT
# [True, False, False, False]
# 348 186
# LEFT
# [True, False, False, False]
# 329 184
# LEFT
# [True, False, False, False]
# 332 184
# LEFT
# [True, False, False, False]
# 331 183
# LEFT
# [True, False, False, False]
# 330 183
# LEFT
# [True, False, False, False]
# 331 183
# LEFT
# [True, False, False, False]
# 331 182
# LEFT
# [True, False, False, False]
# 332 182
# LEFT
# [True, False, False, False]
# 333 182
# LEFT
# [True, False, False, False]
# 331 179
# LEFT
# [True, False, False, False]
# 332 179
# LEFT
# [True, False, False, False]
# 332 181
# LEFT
# [True, False, False, False]
# 331 179
# LEFT
# [True, False, False, False]
# 332 180
# LEFT
# [True, False, False, False]
# 332 181
# LEFT
# [True, False, False, False]
# 331 180
# LEFT
# [True, False, False, False]
# 331 180
# LEFT
# [True, False, False, False]
# 332 181
# LEFT
# [True, False, False, False]
# 331 180
# LEFT
# [True, False, False, False]
# 331 181
# LEFT
# [True, False, False, False]
# 332 181
# LEFT
# [True, True, True, True]
# 354 179
# [True, False, False, False]
# 333 179
# LEFT
# [True, False, False, False]
# 331 179
# LEFT
# [True, False, False, False]
# 332 180
# LEFT
# [True, False, False, False]
# 331 178
# LEFT
# [True, False, False, False]
# 332 179
# LEFT
# [True, False, False, False]
# 332 177
# LEFT
# [True, False, False, False]
# 332 177
# LEFT
# [True, False, False, False]
# 330 177
# LEFT
# [True, False, False, False]
# 332 178
# LEFT
# [True, False, False, False]
# 333 178
# LEFT
# [True, False, False, False]
# 333 178
# LEFT
# [True, False, False, False]
# 331 176
# LEFT
# [True, False, False, False]
# 334 176
# LEFT
# [True, False, False, False]
# 334 176
# LEFT
# [True, False, False, False]
# 334 176
# LEFT
# [True, False, False, False]
# 333 176
# LEFT
# [True, False, False, False]
# 334 176
# LEFT
# [True, False, False, False]
# 335 175
# LEFT
# [True, False, False, False]
# 336 176
# LEFT
# [True, False, False, False]
# 350 178
# LEFT
# [True, False, False, False]
# 336 176
# LEFT
# [True, False, False, False]
# 336 176
# LEFT
# [True, False, False, False]
# 336 174
# LEFT
# [True, False, False, False]
# 336 175
# LEFT
# [True, False, False, False]
# 336 176
# LEFT
# [True, False, False, False]
# 336 175
# LEFT
# [True, False, False, False]
# 336 177
# LEFT
# [True, False, False, False]
# 334 176
# LEFT
# [True, False, False, False]
# 336 177
# LEFT
# [True, False, False, False]
# 334 174
# LEFT
# [True, False, False, False]
# 334 175
# LEFT
# [True, False, False, False]
# 336 174
# LEFT
# [True, False, False, False]
# 336 174
# LEFT
# [True, False, False, False]
# 334 173
# LEFT
# [True, False, False, False]
# 333 173
# LEFT
# [True, False, False, False]
# 339 168
# LEFT
# [True, True, True, True]
# 353 171
# [True, False, False, False]
# 340 168
# LEFT
# [True, False, False, False]
# 340 169
# LEFT
# [True, False, False, False]
# 340 169
# LEFT
# [True, False, False, False]
# 342 169
# LEFT
# [True, False, False, False]
# 342 169
# LEFT
# [True, False, False, False]
# 341 169
# LEFT
# [True, False, False, False]
# 342 170
# LEFT
# [True, False, False, False]
# 341 170
# LEFT
# [True, False, False, False]
# 342 169
# LEFT
# [True, False, False, False]
# 341 168
# LEFT
# [True, False, False, False]
# 340 168
# LEFT
# [True, False, False, False]
# 341 171
# LEFT
# [True, False, False, False]
# 340 170
# LEFT
# [True, True, True, True]
# 375 176
# [True, False, False, False]
# 341 169
# LEFT
# [True, False, False, False]
# 350 174
# LEFT
# [True, False, False, False]
# 341 170
# LEFT
# [True, False, False, False]
# 344 170
# LEFT
# [True, True, True, True]
# 369 176
# [True, False, False, False]
# 344 170
# LEFT
# [True, False, False, False]
# 340 170
# LEFT
# [True, False, False, False]
# 342 170
# LEFT
# [True, False, False, False]
# 342 170
# LEFT
# [True, False, False, False]
# 342 170
# LEFT
# [True, False, False, False]
# 343 171
# LEFT
# [True, False, False, False]
# 345 171
# LEFT
# [False, False, False, False]
# 222 268
# [False, True, True, True]
# 273 268
# RIGHT
# [False, True, True, True]
# 273 269
# RIGHT
# [False, True, True, True]
# 275 264
# RIGHT
# [False, True, True, True]
# 268 249
# RIGHT
# [False, True, True, True]
# 261 233
# RIGHT
# [False, True, True, True]
# 264 231
# RIGHT
# [False, True, True, True]
# 258 229
# RIGHT
# [False, True, True, True]
# 261 233
# RIGHT
# [False, True, True, True]
# 261 233
# RIGHT
# [False, True, True, True]
# 258 229
# RIGHT
# [False, True, True, True]
# 257 229
# RIGHT
# [False, True, True, True]
# 258 227
# RIGHT
# [False, True, True, True]
# 256 229
# RIGHT
# [False, True, True, True]
# 255 228
# RIGHT
# [False, True, True, True]
# 259 229
# RIGHT
# [False, True, True, True]
# 261 229
# RIGHT
# [False, True, True, True]
# 261 230
# RIGHT
# [False, True, True, True]
# 260 231
# RIGHT
# [False, True, True, True]
# 261 232
# RIGHT
# [False, True, True, True]
# 262 232
# RIGHT
# [False, True, True, True]
# 259 235
# RIGHT
# [False, True, True, True]
# 258 241
# RIGHT
# [False, True, True, True]
# 257 241
# RIGHT
# [False, True, True, True]
# 258 240
# RIGHT
# [False, True, True, True]
# 258 241
# RIGHT
# [False, True, True, True]
# 258 242
# RIGHT
# [False, True, True, True]
# 260 241
# RIGHT
# [False, True, True, True]
# 258 242
# RIGHT
# [False, True, True, True]
# 259 242
# RIGHT
# [False, True, True, True]
# 260 241
# RIGHT
# [False, True, True, True]
# 259 240
# RIGHT
# [False, True, True, True]
# 259 240
# RIGHT
# [False, True, True, True]
# 261 241
# RIGHT
# [False, True, True, True]
# 260 240
# RIGHT
# [False, True, True, True]
# 259 240
# RIGHT
# [False, True, True, True]
# 261 240
# RIGHT
# [False, True, True, True]
# 259 240
# RIGHT
# [False, True, True, True]
# 263 243
# RIGHT
# [False, True, True, True]
# 261 242
# RIGHT
# [False, True, True, True]
# 259 243
# RIGHT
# [False, True, True, True]
# 259 241
# RIGHT
# [False, True, True, True]
# 261 243
# RIGHT
# [False, True, True, True]
# 260 243
# RIGHT
# [False, True, True, True]
# 261 244
# RIGHT
# [False, True, True, True]
# 261 244
# RIGHT
# [False, True, True, True]
# 258 244
# RIGHT
# [False, True, True, True]
# 261 244
# RIGHT
# [False, True, True, True]
# 261 244
# RIGHT
# [False, True, True, True]
# 261 244
# RIGHT
# [False, True, True, True]
# 262 243
# RIGHT
# [False, True, True, True]
# 260 243
# RIGHT
# [False, True, True, True]
# 262 245
# RIGHT
# [False, True, True, True]
# 262 243
# RIGHT
# [False, True, True, True]
# 261 243
# RIGHT
# [False, True, True, True]
# 260 243
# RIGHT
# [False, True, True, True]
# 262 242
# RIGHT
# [False, True, True, True]
# 262 243
# RIGHT
# [False, True, True, True]
# 261 244
# RIGHT
# [False, True, True, True]
# 262 243
# RIGHT
# [False, True, True, True]
# 262 243
# RIGHT
# [False, True, True, True]
# 261 242
# RIGHT
# [False, True, True, True]
# 261 244
# RIGHT
# [False, True, True, True]
# 263 246
# RIGHT
# [False, True, True, True]
# 264 250
# RIGHT
# [False, False, False, False]
# 197 176
# [False, False, False, False]
# 189 176
# [False, False, False, False]
# 186 170
# [False, False, False, False]
# 205 178
# [False, False, False, False]
# 213 191
# [False, False, False, False]
# 213 201
# [False, False, False, False]
# 208 201
# [False, False, False, False]
# 205 201
# [False, False, False, False]
# 207 199
# [False, False, False, False]
# 202 198
# [False, False, False, False]
# 205 191
# [False, False, False, False]
# 209 194
# [False, False, False, False]
# 202 201
# [False, False, False, False]
# 199 200
# [False, False, False, False]
# 182 191
# [False, False, False, False]
# 174 206
# [True, True, True, True]
# 409 107
# FORWARD
# [True, True, True, True]
# 407 108
# FORWARD
# [False, False, False, False]
# 530 364
# [True, True, True, True]
# 411 111
# FORWARD
# [True, True, True, True]
# 414 118
# FORWARD
# [True, True, True, True]
# 415 118
# FORWARD
# [True, True, True, True]
# 418 138
# FORWARD
# [True, True, True, True]
# 419 150
# FORWARD
# [True, True, True, True]
# 420 149
# FORWARD
# [True, True, True, True]
# 421 161
# FORWARD
# [True, True, True, True]
# 422 160
# FORWARD
# [True, True, True, True]
# 419 172
# FORWARD
# [True, True, True, True]
# 414 158
# FORWARD
# [True, True, True, True]
# 415 160
# FORWARD
# [True, False, True, True]
# 411 207
# [True, True, True, True]
# 414 202
# [True, True, True, True]
# 416 214
# [True, True, True, True]
# 380 147
# FORWARD
# [True, True, True, True]
# 385 87
# FORWARD
# [True, True, True, True]
# 381 87
# FORWARD
# [True, True, True, True]
# 377 100
# FORWARD
# [True, True, True, True]
# 377 120
# FORWARD
# [True, True, True, True]
# 400 112
# FORWARD
# [False, True, True, True]
# 418 94
# FORWARD
# RIGHT
# [False, True, True, True]
# 428 101
# FORWARD
# RIGHT
# [False, True, True, True]
# 446 106
# FORWARD
# RIGHT
# [True, True, True, True]
# 414 165
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 19
#      17 img = cv2.flip(img, 1)
#      18 h, w, c = img.shape
# ---> 19 results = hands.process(img)
#      21 if results.multi_hand_landmarks:
#      22     for hand_landmark in results.multi_hand_landmarks:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solutions\hands.py:153, in Hands.process(self, image)
#     132 def process(self, image: np.ndarray) -> NamedTuple:
#     133   """Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#     134
#     135   Args:
#    (...)
#     150          right hand) of the detected hand.
#     151   """
# --> 153   return super().process(input_data={'image': image})
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\mediapipe\python\solution_base.py:365, in SolutionBase.process(self, input_data)
#     359   else:
#     360     self._graph.add_packet_to_input_stream(
#     361         stream=stream_name,
#     362         packet=self._make_packet(input_stream_type,
#     363                                  data).at(self._simulated_timestamp))
# --> 365 self._graph.wait_until_idle()
#     366 # Create a NamedTuple object where the field names are mapping to the graph
#     367 # output stream names.
#     368 solution_outputs = collections.namedtuple(
#     369     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
